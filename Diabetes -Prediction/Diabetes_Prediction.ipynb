# %% [markdown]
# # Diabetes Prediction ML Project
#   * Support vector machine  -(Supervised Learning algo)
#
#   workflow:-
#
#   Data >>> Data Processing >>  Train - Test split >>  Support Vector Machine  Classifer
