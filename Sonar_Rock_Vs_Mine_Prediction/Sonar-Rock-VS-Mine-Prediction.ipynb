# %% [markdown]
# # Start the first ML  "Sonar Rock vs Mine Predicition ML Project"

# %% [markdown]
# ### Steps to create project
#    * Data Collection
#    * Data Pre Processing
#    * Train Test Split
#    * Logistic Regression model (supervised learning model)
